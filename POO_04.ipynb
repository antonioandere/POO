# %%
jugadores={"Messi":[34,42,40,56,91,63,70,42,33,26],"Lewandowski":[77,45,56,43,23,56,28,30,41,39],"Vinicius":[11,14,17,22,14,32,29,21,20,18],"Haaland":[24,34,43,21,43,56,43,23,45,56],"Mbappe":[44,43,51,24,36,28,54,34,32,33],"Torres":[26,29,31,34,10,23,34,43,21,19],"Villa":[17,19,22,34,12,34,23,15,45,33],"Pedri":[12,14,14,17,21,10,15,18,29,17],"Müller":[12,23,34,32,21,23,43,21,32,27],"Bravo":[17,18,22,19,23,23,18,23,17,29]}

# %%
print(jugadores)
# Out:
# {'Messi': [34, 42, 40, 56, 91, 63, 70, 42, 33, 26], 'Lewandowski': [77, 45, 56, 43, 23, 56, 28, 30, 41, 39], 'Vinicius': [11, 14, 17, 22, 14, 32, 29, 21, 20, 18], 'Haaland': [24, 34, 43, 21, 43, 56, 43, 23, 45, 56], 'Mbappe': [44, 43, 51, 24, 36, 28, 54, 34, 32, 33], 'Torres': [26, 29, 31, 34, 10, 23, 34, 43, 21, 19], 'Villa': [17, 19, 22, 34, 12, 34, 23, 15, 45, 33], 'Pedri': [12, 14, 14, 17, 21, 10, 15, 18, 29, 17], 'Müller': [12, 23, 34, 32, 21, 23, 43, 21, 32, 27], 'Bravo': [17, 18, 22, 19, 23, 23, 18, 23, 17, 29]}

# %%
import pandas as pd

# %%
goles = pd.DataFrame(jugadores)

# %%
goles
# Out:
#    Messi  Lewandowski  Vinicius  Haaland  Mbappe  Torres  Villa  Pedri  \
# 0     34           77        11       24      44      26     17     12
# 1     42           45        14       34      43      29     19     14
# 2     40           56        17       43      51      31     22     14
# 3     56           43        22       21      24      34     34     17
# 4     91           23        14       43      36      10     12     21
# 5     63           56        32       56      28      23     34     10
# 6     70           28        29       43      54      34     23     15
# 7     42           30        21       23      34      43     15     18
# 8     33           41        20       45      32      21     45     29
# 9     26           39        18       56      33      19     33     17
#
#    Müller  Bravo
# 0      12     17
# 1      23     18
# 2      34     22
# 3      32     19
# 4      21     23
# 5      23     23
# 6      43     18
# 7      21     23
# 8      32     17
# ...

# %% [markdown]
# # Tarea 1.2 PARTE A
# ## Antonio Andere, Manuel Alonso y Emiliano Trueba

# %%
#1 Monta el archivo en tu Drive y da lectura en un panel de datos.
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
dr = pd.read_csv("/content/drive/MyDrive/Data Base/daily_returns.csv")
dr
# Out:
#       Unnamed: 0      AAPL       JPM       WMT       TGT      MSFT      AMGN
# 0     2000-01-03  0.088754 -0.061947 -0.033454 -0.018723 -0.001606  0.047867
# 1     2000-01-04 -0.084310 -0.027444 -0.037418 -0.043365 -0.033780 -0.076465
# 2     2000-01-05  0.014634 -0.006173 -0.020408 -0.022665  0.010544  0.034409
# 3     2000-01-06 -0.086538  0.014197  0.010913 -0.047310 -0.033498  0.016632
# 4     2000-01-07  0.047368  0.018373  0.075564  0.051607  0.013068  0.112474
# ...          ...       ...       ...       ...       ...       ...       ...
# 4687  2018-08-20 -0.009744 -0.001307 -0.018906  0.003372 -0.006600  0.000709
# 4688  2018-08-21 -0.001949  0.006107  0.000833 -0.000600 -0.008328 -0.001265
# 4689  2018-08-22  0.000047 -0.003035 -0.004267  0.032064  0.010191  0.002686
# 4690  2018-08-23  0.002046 -0.002087 -0.005122  0.008960  0.004670 -0.006268
# 4691  2018-08-24  0.003109 -0.000436 -0.002417  0.006920  0.007810  0.000203
#
# [4692 rows x 7 columns]

# %%
#2 Cambia la columna Unnamed: 0 y ponla como índice.
dr.set_index("Unnamed: 0", inplace=True)
dr
# Out:
#                 AAPL       JPM       WMT       TGT      MSFT      AMGN
# Unnamed: 0
# 2000-01-03  0.088754 -0.061947 -0.033454 -0.018723 -0.001606  0.047867
# 2000-01-04 -0.084310 -0.027444 -0.037418 -0.043365 -0.033780 -0.076465
# 2000-01-05  0.014634 -0.006173 -0.020408 -0.022665  0.010544  0.034409
# 2000-01-06 -0.086538  0.014197  0.010913 -0.047310 -0.033498  0.016632
# 2000-01-07  0.047368  0.018373  0.075564  0.051607  0.013068  0.112474
# ...              ...       ...       ...       ...       ...       ...
# 2018-08-20 -0.009744 -0.001307 -0.018906  0.003372 -0.006600  0.000709
# 2018-08-21 -0.001949  0.006107  0.000833 -0.000600 -0.008328 -0.001265
# 2018-08-22  0.000047 -0.003035 -0.004267  0.032064  0.010191  0.002686
# 2018-08-23  0.002046 -0.002087 -0.005122  0.008960  0.004670 -0.006268
# 2018-08-24  0.003109 -0.000436 -0.002417  0.006920  0.007810  0.000203
#
# [4692 rows x 6 columns]

# %%
#3 Calcula la media y varianza de cada ticker
md=dr.mean(axis=0)
md
# Out:
# AAPL    0.001220
# JPM     0.000476
# WMT     0.000182
# TGT     0.000390
# MSFT    0.000317
# AMGN    0.000458
# dtype: float64

# %%
v=dr.var(axis=0)
v
# Out:
# AAPL    0.000669
# JPM     0.000620
# WMT     0.000229
# TGT     0.000412
# MSFT    0.000371
# AMGN    0.000413
# dtype: float64

# %%
AAPL=dr.iloc[:,[0]]
AAPL
# Out:
#                 AAPL
# Unnamed: 0
# 2000-01-03  0.088754
# 2000-01-04 -0.084310
# 2000-01-05  0.014634
# 2000-01-06 -0.086538
# 2000-01-07  0.047368
# ...              ...
# 2018-08-20 -0.009744
# 2018-08-21 -0.001949
# 2018-08-22  0.000047
# 2018-08-23  0.002046
# 2018-08-24  0.003109
#
# [4692 rows x 1 columns]

# %%
media=AAPL.mean()
desv=AAPL.std()
def TRANS(AAPL,media,desv):
  x=(AAPL-media)/desv
  return x

TRANS(AAPL,media,desv)
# Out:
#                 AAPL
# Unnamed: 0
# 2000-01-03  3.385338
# 2000-01-04 -3.307829
# 2000-01-05  0.518797
# 2000-01-06 -3.393996
# 2000-01-07  1.784781
# ...              ...
# 2018-08-20 -0.423994
# 2018-08-21 -0.122559
# 2018-08-22 -0.045368
# 2018-08-23  0.031962
# 2018-08-24  0.073078
#
# [4692 rows x 1 columns]

# %%
JPM=dr.iloc[:,[1]]
JPM
# Out:
#                  JPM
# Unnamed: 0
# 2000-01-03 -0.061947
# 2000-01-04 -0.027444
# 2000-01-05 -0.006173
# 2000-01-06  0.014197
# 2000-01-07  0.018373
# ...              ...
# 2018-08-20 -0.001307
# 2018-08-21  0.006107
# 2018-08-22 -0.003035
# 2018-08-23 -0.002087
# 2018-08-24 -0.000436
#
# [4692 rows x 1 columns]

# %%
mediaJPM=JPM.mean()
desvJPM=JPM.std()


TRANS(JPM,mediaJPM,desvJPM)
# Out:
#                  JPM
# Unnamed: 0
# 2000-01-03 -2.507045
# 2000-01-04 -1.121349
# 2000-01-05 -0.267050
# 2000-01-06  0.551044
# 2000-01-07  0.718747
# ...              ...
# 2018-08-20 -0.071624
# 2018-08-21  0.226138
# 2018-08-22 -0.141028
# 2018-08-23 -0.102973
# 2018-08-24 -0.036640
#
# [4692 rows x 1 columns]

# %%
WMT=dr.iloc[:,[2]]

WMT
# Out:
#                  WMT
# Unnamed: 0
# 2000-01-03 -0.033454
# 2000-01-04 -0.037418
# 2000-01-05 -0.020408
# 2000-01-06  0.010913
# 2000-01-07  0.075564
# ...              ...
# 2018-08-20 -0.018906
# 2018-08-21  0.000833
# 2018-08-22 -0.004267
# 2018-08-23 -0.005122
# 2018-08-24 -0.002417
#
# [4692 rows x 1 columns]

# %%
mw=WMT.mean()
dw=WMT.std()


TRANS(WMT,mw,dw)
# Out:
#                  WMT
# Unnamed: 0
# 2000-01-03 -2.224458
# 2000-01-04 -2.486630
# 2000-01-05 -1.361691
# 2000-01-06  0.709684
# 2000-01-07  4.985353
# ...              ...
# 2018-08-20 -1.262379
# 2018-08-21  0.043096
# 2018-08-22 -0.294232
# 2018-08-23 -0.350739
# 2018-08-24 -0.171831
#
# [4692 rows x 1 columns]

# %%
TGT=dr.iloc[:,[3]]
TGT
# Out:
#                  TGT
# Unnamed: 0
# 2000-01-03 -0.018723
# 2000-01-04 -0.043365
# 2000-01-05 -0.022665
# 2000-01-06 -0.047310
# 2000-01-07  0.051607
# ...              ...
# 2018-08-20  0.003372
# 2018-08-21 -0.000600
# 2018-08-22  0.032064
# 2018-08-23  0.008960
# 2018-08-24  0.006920
#
# [4692 rows x 1 columns]

# %%
mt=TGT.mean()
dt=TGT.std()


TRANS(TGT,mt,dt)
# Out:
#                  TGT
# Unnamed: 0
# 2000-01-03 -0.941238
# 2000-01-04 -2.154687
# 2000-01-05 -1.135359
# 2000-01-06 -2.348938
# 2000-01-07  2.522070
# ...              ...
# 2018-08-20  0.146813
# 2018-08-21 -0.048782
# 2018-08-22  1.559741
# 2018-08-23  0.421979
# 2018-08-24  0.321517
#
# [4692 rows x 1 columns]

# %%
MSFT=dr.iloc[:,[4]]

MSFT
# Out:
#                 MSFT
# Unnamed: 0
# 2000-01-03 -0.001606
# 2000-01-04 -0.033780
# 2000-01-05  0.010544
# 2000-01-06 -0.033498
# 2000-01-07  0.013068
# ...              ...
# 2018-08-20 -0.006600
# 2018-08-21 -0.008328
# 2018-08-22  0.010191
# 2018-08-23  0.004670
# 2018-08-24  0.007810
#
# [4692 rows x 1 columns]

# %%
mm=MSFT.mean()
dm=MSFT.std()


TRANS(MSFT,mm,dm)
# Out:
#                 MSFT
# Unnamed: 0
# 2000-01-03 -0.099823
# 2000-01-04 -1.769649
# 2000-01-05  0.530749
# 2000-01-06 -1.755009
# 2000-01-07  0.661761
# ...              ...
# 2018-08-20 -0.358996
# 2018-08-21 -0.448685
# 2018-08-22  0.512413
# 2018-08-23  0.225913
# 2018-08-24  0.388845
#
# [4692 rows x 1 columns]

# %%
AMGN=dr.iloc[:,[5]]
AMGN
# Out:
#                 AMGN
# Unnamed: 0
# 2000-01-03  0.047867
# 2000-01-04 -0.076465
# 2000-01-05  0.034409
# 2000-01-06  0.016632
# 2000-01-07  0.112474
# ...              ...
# 2018-08-20  0.000709
# 2018-08-21 -0.001265
# 2018-08-22  0.002686
# 2018-08-23 -0.006268
# 2018-08-24  0.000203
#
# [4692 rows x 1 columns]

# %%
mam=AMGN.mean()
dam=AMGN.std()


TRANS(AMGN,mam,dam)
# Out:
#                 AMGN
# Unnamed: 0
# 2000-01-03  2.333518
# 2000-01-04 -3.786244
# 2000-01-05  1.671088
# 2000-01-06  0.796101
# 2000-01-07  5.513591
# ...              ...
# 2018-08-20  0.012356
# 2018-08-21 -0.084835
# 2018-08-22  0.109666
# 2018-08-23 -0.331050
# 2018-08-24 -0.012536
#
# [4692 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
from pylab import plot

import seaborn as sns

# %%
dr["AAPL"].plot(label="AAPL", figsize = (15,8))
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
dr.describe()
# Out:
#               AAPL          JPM          WMT          TGT         MSFT  \
# count  4692.000000  4692.000000  4692.000000  4692.000000  4692.000000
# mean      0.001220     0.000476     0.000182     0.000390     0.000317
# std       0.025857     0.024899     0.015121     0.020307     0.019268
# min      -0.518692    -0.207274    -0.101832    -0.125000    -0.155978
# 25%      -0.010588    -0.009133    -0.006988    -0.009091    -0.008289
# 50%       0.000758     0.000000     0.000203     0.000204     0.000000
# 75%       0.013159     0.009709     0.006932     0.009378     0.008728
# max       0.139050     0.250967     0.110731     0.178036     0.195652
#
#               AMGN
# count  4692.000000
# mean      0.000458
# std       0.020316
# min      -0.134124
# 25%      -0.009081
# 50%       0.000000
# 75%       0.009771
# max       0.151021

# %% [markdown]
# # PARTE B

# %%
import math

def circulo(radio):
  xc= math.pi * (radio ** 2)
  return xc

# %%
def rectangulo(base, altura):
  xr=base*altura
  return xr

# %%
import math
def rstq(numero):
  xsqrt=math.sqrt(numero)
  return xsqrt

# %%
rstq(81)
# Out:
# 9.0

# %%
rectangulo(8,3)
# Out:
# 24

# %%
circulo(5)
# Out:
# 78.53981633974483

# %%
import random


l = [random.randint(0, 100) for _ in range(20)]


print(l)
# Out:
# [100, 61, 13, 43, 97, 100, 26, 79, 97, 99, 19, 62, 61, 71, 99, 54, 100, 18, 54, 81]

# %%
r = [raiz(numero) for numero in l]
r
# Out:
# [10.0,
#  7.810249675906654,
#  3.605551275463989,
#  6.557438524302,
#  9.848857801796104,
#  10.0,
#  5.0990195135927845,
#  8.888194417315589,
#  9.848857801796104,
#  9.9498743710662,
#  4.358898943540674,
#  7.874007874011811,
#  7.810249675906654,
#  8.426149773176359,
#  9.9498743710662,
#  7.3484692283495345,
#  10.0,
#  4.242640687119285,
#  7.3484692283495345,
#  9.0]

# %%
enteros = {
    numero
    for numero in l
    if math.sqrt(numero).is_integer()
}
print(enteros)
# Out:
# {81, 100}

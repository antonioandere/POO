# %% [markdown]
# ## Tarea 1. Primera parte.

# %% [markdown]
# 1.   Genera una lista que consista de $20$ números que estén en el intervalo $[-1,1]$. Llámala `Lista_1`.
# 2.   Genera una lista que consista de $20$ números que sean enteros en el intervalo $[1500, 3000]$. Llámala `Lista_2`.
# 3. Crea un diccionario cuyas llaves sean "**CapSmall**" y "**CapLarge**" y sus valores sean la `Lista_1` y `Lista_2`, respectivamente.
# 4. Crea un `DataFrame` a partir del diccionario del punto anterior. Llámalo df.
# 5. Reindexa los índices poniendo Año 1$,...,$ Año 20.
# 6. Realiza una explicación de la estadística descriptiva de tu `DataFrame`.
# 7. ¿Cuál es el valor mínimo de la columna "**CapSmall**"?
# 8. ¿Cuál es "**CapLarge**" promedio del año 10 al año 20.
# 9. Realiza una gráfica de Año contra "**CapLarge**".
# 10. Muestra el `DataFrame` que obtienes si tomas aquellos valores de "**CapLarge**" mayores a $2000$. ¿Cuál es la dimensión (shape) de tu nueva base de datos?

# %%
import numpy as np
import pandas as pd

# %%
Lista_1=[np.random.uniform (-1,1)  for _  in range (20)]
print(Lista_1)
# Out:
# [-0.33277412240443005, -0.2063849470976602, -0.24369641784676999, -0.7254413529555355, 0.6939817545660614, 0.5565588871109259, -0.07110487457365999, 0.49301050913804123, 0.3436349600975712, 0.7987597160803286, 0.5552930298766334, -0.2171169749385713, 0.20535683669065974, -0.6161989748380623, 0.6244440194286607, -0.5383607722912305, 0.015248692963682364, 0.6544406692591274, -0.18094458299361715, -0.7355201324961267]

# %%
Lista_1
# Out:
# [-0.33277412240443005,
#  -0.2063849470976602,
#  -0.24369641784676999,
#  -0.7254413529555355,
#  0.6939817545660614,
#  0.5565588871109259,
#  -0.07110487457365999,
#  0.49301050913804123,
#  0.3436349600975712,
#  0.7987597160803286,
#  0.5552930298766334,
#  -0.2171169749385713,
#  0.20535683669065974,
#  -0.6161989748380623,
#  0.6244440194286607,
#  -0.5383607722912305,
#  0.015248692963682364,
#  0.6544406692591274,
#  -0.18094458299361715,
#  -0.7355201324961267]

# %%
Lista_2=[np.random.randint(1500,3000) for _ in range(20)]
print(Lista_2)
# Out:
# [1884, 1763, 2585, 1884, 1899, 1984, 2576, 2191, 1621, 1746, 1804, 1520, 2695, 2939, 2009, 2379, 2978, 2967, 2160, 2712]

# %%
Lista_2
# Out:
# [1884,
#  1763,
#  2585,
#  1884,
#  1899,
#  1984,
#  2576,
#  2191,
#  1621,
#  1746,
#  1804,
#  1520,
#  2695,
#  2939,
#  2009,
#  2379,
#  2978,
#  2967,
#  2160,
#  2712]

# %%
Dictionary={"Capsmall":[0.6877781360095077,
 -0.14200739993856404,
 0.7710897867782802,
 -0.5378888478323616,
 0.7629943638254482,
 0.29364044823676494,
 0.5878683184309883,
 0.5692154594588577,
 0.35314944715461527,
 -0.5521557658076099,
 -0.5259878117969532,
 -0.6564608180647558,
 -0.8981484567966478,
 0.38753041058275484,
 -0.6622249393250177,
 -0.7844651932260174,
 -0.5713841936406114,
 0.3606301896594142,
 -0.8730021146927902,
 0.08496934937345069],"Caplarge":[2803,
 2819,
 1795,
 2128,
 2222,
 2018,
 2054,
 1712,
 2886,
 1835,
 2065,
 2068,
 2614,
 2895,
 2554,
 2014,
 2487,
 2738,
 2313,
 2355]}

# %%
Dictionary
# Out:
# {'Capsmall': [0.6877781360095077,
#   -0.14200739993856404,
#   0.7710897867782802,
#   -0.5378888478323616,
#   0.7629943638254482,
#   0.29364044823676494,
#   0.5878683184309883,
#   0.5692154594588577,
#   0.35314944715461527,
#   -0.5521557658076099,
#   -0.5259878117969532,
#   -0.6564608180647558,
#   -0.8981484567966478,
#   0.38753041058275484,
#   -0.6622249393250177,
#   -0.7844651932260174,
#   -0.5713841936406114,
#   0.3606301896594142,
#   -0.8730021146927902,
#   0.08496934937345069],
#  'Caplarge': [2803,
#   2819,
#   1795,
#   2128,
#   2222,
#   2018,
#   2054,
#   1712,
#   2886,
#   1835,
#   2065,
#   2068,
#   2614,
#   2895,
#   2554,
#   2014,
#   2487,
#   2738,
#   2313,
#   2355]}

# %%
dataframe=pd.DataFrame(Dictionary)
Dictionary
# Out:
# {'Capsmall': [0.6877781360095077,
#   -0.14200739993856404,
#   0.7710897867782802,
#   -0.5378888478323616,
#   0.7629943638254482,
#   0.29364044823676494,
#   0.5878683184309883,
#   0.5692154594588577,
#   0.35314944715461527,
#   -0.5521557658076099,
#   -0.5259878117969532,
#   -0.6564608180647558,
#   -0.8981484567966478,
#   0.38753041058275484,
#   -0.6622249393250177,
#   -0.7844651932260174,
#   -0.5713841936406114,
#   0.3606301896594142,
#   -0.8730021146927902,
#   0.08496934937345069],
#  'Caplarge': [2803,
#   2819,
#   1795,
#   2128,
#   2222,
#   2018,
#   2054,
#   1712,
#   2886,
#   1835,
#   2065,
#   2068,
#   2614,
#   2895,
#   2554,
#   2014,
#   2487,
#   2738,
#   2313,
#   2355]}

# %%
dataframe=pd.DataFrame(Dictionary,index=["año1","año2","año3","año4","año5","año6","año7","año8","año9","año10","año11","año12","año13","año14","año15","año16","año17","año18","año19","año20"])
dataframe
# Out:
#        Capsmall  Caplarge
# año1   0.687778      2803
# año2  -0.142007      2819
# año3   0.771090      1795
# año4  -0.537889      2128
# año5   0.762994      2222
# año6   0.293640      2018
# año7   0.587868      2054
# año8   0.569215      1712
# año9   0.353149      2886
# año10 -0.552156      1835
# año11 -0.525988      2065
# año12 -0.656461      2068
# año13 -0.898148      2614
# año14  0.387530      2895
# año15 -0.662225      2554
# año16 -0.784465      2014
# año17 -0.571384      2487
# año18  0.360630      2738
# año19 -0.873002      2313
# año20  0.084969      2355

# %%
dataframe.describe()
# Out:
#         Capsmall     Caplarge
# count  20.000000    20.000000
# mean   -0.067243  2318.750000
# std     0.606913   383.160386
# min    -0.898148  1712.000000
# 25%    -0.592653  2045.000000
# 50%    -0.028519  2267.500000
# 75%     0.432952  2645.000000
# max     0.771090  2895.000000

# %%
valor_minimo = dataframe.min()
valor_minimo
# Out:
# Capsmall      -0.898148
# Caplarge    1712.000000
# dtype: float64

# %%
Caplarge_promedio=dataframe.iloc[10:20]
Caplarge_promedio=Caplarge_promedio.drop(columns="Capsmall")
Caplarge_promedio
# Out:
#        Caplarge
# año11      2065
# año12      2068
# año13      2614
# año14      2895
# año15      2554
# año16      2014
# año17      2487
# año18      2738
# año19      2313
# año20      2355

# %%
Caplarge_promedio.mean()
# Out:
# Caplarge    2410.3
# dtype: float64

# %%
dataframe_Capsmall=dataframe.drop(columns="Capsmall")
dataframe_Capsmall
# Out:
#        Caplarge
# año1       2803
# año2       2819
# año3       1795
# año4       2128
# año5       2222
# año6       2018
# año7       2054
# año8       1712
# año9       2886
# año10      1835
# año11      2065
# año12      2068
# año13      2614
# año14      2895
# año15      2554
# año16      2014
# año17      2487
# año18      2738
# año19      2313
# año20      2355
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(dataframe_Capsmall, *['Caplarge'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(dataframe_Capsmall, *['Caplarge'], **{})
# chart

# %%
mayora2000=dataframe["Caplarge"]>2000
filtrodataframe=dataframe[mayora2000]
filtrodataframe
# Out:
#        Capsmall  Caplarge
# año1   0.687778      2803
# año2  -0.142007      2819
# año4  -0.537889      2128
# año5   0.762994      2222
# año6   0.293640      2018
# año7   0.587868      2054
# año9   0.353149      2886
# año11 -0.525988      2065
# año12 -0.656461      2068
# año13 -0.898148      2614
# año14  0.387530      2895
# año15 -0.662225      2554
# año16 -0.784465      2014
# año17 -0.571384      2487
# año18  0.360630      2738
# año19 -0.873002      2313
# año20  0.084969      2355
